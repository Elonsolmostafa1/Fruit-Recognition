# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from numpy.lib.polynomial import poly
import cvlib as cv
from cvlib.object_detection import draw_bbox
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20288/822062302.py in <module>
#       3 import matplotlib.pyplot as plt
#       4 from numpy.lib.polynomial import poly
# ----> 5 import cvlib as cv
#       6 from cvlib.object_detection import draw_bbox
#
# C:\ProgramData\Anaconda3\lib\site-packages\cvlib\__init__.py in <module>
#       6 from .face_detection import detect_face
#       7 from .object_detection import detect_common_objects
# ----> 8 from .gender_detection import detect_gender
#       9 from .utils import get_frames, animate
#
# C:\ProgramData\Anaconda3\lib\site-packages\cvlib\gender_detection.py in <module>
#       1 import os
#       2 import cv2
# ----> 3 from tensorflow.keras.utils import get_file
#       4
#       5 initialize = True
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
img = cv2.imread('O1.jpg')
img1 = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,10))
plt.axis('off')
plt.imshow(img1)
plt.show()

# %%
box, label, count = cv2.detect_common_objects(img)
output = draw_bbox(img, box, label, count)
